# %%
pip install ucimlrepo
# Out:
# ...
#   Obtaining dependency information for ucimlrepo from https://files.pythonhosted.org/packages/3e/4a/ecc3456479d687202b34ee42317c3a63e09793c9409a720052d38356431a/ucimlrepo-0.0.3-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine_quality = fetch_ucirepo(id=186)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://archive.ics.uci.edu/static/public/186/data.csv')
df.to_csv('wine.csv', index = False)

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
df.shape
# Out:
# (6497, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 6427            6.4             0.230         0.35           10.30      0.042
# 6449            7.0             0.360         0.35            2.50      0.048
# 6450            6.4             0.330         0.44            8.90      0.055
# 6455            7.1             0.230         0.39           13.70      0.058
# 6479            6.6             0.340         0.40            8.10      0.046
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (5320, 13)

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    5320.000000       5320.000000  5320.000000     5320.000000
# mean        7.215179          0.344130     0.318494        5.048477
# std         1.319671          0.168248     0.147157        4.500180
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  5320.000000          5320.000000           5320.000000  5320.000000
# mean      0.056690            30.036654            114.109023     0.994535
# std       0.036863            17.805045             56.774223     0.002966
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ### Boxplot

# %%
for i in df.columns:
    if df[i].dtypes != 'object':
        # Create a boxplot
        plt.figure(figsize=(8, 6))
        sns.boxplot(df[i])
        plt.title('Boxplot of {}'.format(i))
        plt.show()

# %% [markdown]
# This Boxplot shows that columns have more outliers hence I am performing IQR method to handle outliers

# %%
def iqr(df):
    for i in df.columns:
        if df[i].dtypes != 'object':
            Q1 = df[i].quantile(0.25)
            Q3 = df[i].quantile(0.75)
            IQR = Q3 - Q1
            threshold = 1.5 * IQR
            lower_bound = Q1 - threshold
            upper_bound = Q3 + threshold

            outliers = df[(df[i].values < lower_bound) | (df[i].values > upper_bound)]
            df[i].values[df[i].values < lower_bound] = lower_bound
            df[i].values[df[i].values > upper_bound] = upper_bound
    return df

# %%
df = iqr(df)

# %%
for i in df.columns:
    if df[i].dtypes != 'object':
        # Create a boxplot
        plt.figure(figsize=(8, 6))
        sns.boxplot(df[i])
        plt.title('Boxplot of {}'.format(i))
        plt.show()

# %%
for i in df.columns:
    if df[i].dtypes != 'object':
        # Create a boxplot
        plt.figure(figsize=(8, 6))
        sns.histplot(df[i], bins=5, kde=False, color='skyblue')
        plt.title('Boxplot of {}'.format(i))
        plt.show()

# %%
for i in df.columns:
    if df[i].dtypes != 'object':
        import statsmodels.api as sm
        fig, ax = plt.subplots(figsize=(8, 6))
        sm.qqplot(df[i], line='s', ax=ax)
        plt.title('Q-Q Plot {}'.format(i))
        plt.show()

# %%
def shapiro(df):
    import scipy.stats as stats
    for i in df.columns:
        if df[i].dtypes != 'object':
            # Check if col1 is normally distributed
            stat, p = stats.shapiro(df[i])
            alpha = 0.05
            if p > alpha:
                print(f"{df[i].name} is normally distributed (fail to reject H0)")
            else:
                print(f"{df[i].name} is not normally distributed (reject H0)")

# %%
print(shapiro(df))
# Out:
# fixed_acidity is not normally distributed (reject H0)
# volatile_acidity is not normally distributed (reject H0)
# citric_acid is not normally distributed (reject H0)
# residual_sugar is not normally distributed (reject H0)
# chlorides is not normally distributed (reject H0)
# free_sulfur_dioxide is not normally distributed (reject H0)
# total_sulfur_dioxide is not normally distributed (reject H0)
# density is not normally distributed (reject H0)
# pH is not normally distributed (reject H0)
# sulphates is not normally distributed (reject H0)
# alcohol is not normally distributed (reject H0)
# quality is not normally distributed (reject H0)
# None
# C:\Users\sudar\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
from sklearn.preprocessing import RobustScaler
import statistics as stats
mm = RobustScaler()

df_mm = pd.DataFrame(mm.fit_transform(df.drop(['color', 'quality'], axis=1)), columns=df.drop(['color', 'quality'], axis=1).columns)

df_mm['color'] = df['color']
df_mm['quality'] = df['quality']
print(df_mm.head(3))
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0       0.307692          2.111111      -1.9375       -0.140351   1.035714
# 1       0.615385          2.111111      -1.9375       -0.017544   1.821429
# 2       0.615385          2.111111      -1.6875       -0.070175   1.607143
#
#    free_sulfur_dioxide  total_sulfur_dioxide   density        pH  sulphates  \
# 0                -0.68             -1.034700  0.689278  1.363636   0.294118
# 1                -0.12             -0.618297  0.470460 -0.045455   1.000000
# 2                -0.52             -0.782334  0.514223  0.227273   0.823529
#
#     alcohol color  quality
# 0 -0.526316   red      5.0
# 1 -0.315789   red      5.0
# 2 -0.315789   red      5.0

# %%
for i in df_mm.columns:
    if df_mm[i].dtypes != 'object':
        import statsmodels.api as sm
        fig, ax = plt.subplots(figsize=(8, 6))
        sm.qqplot(df_mm[i], line='s', ax=ax)
        plt.title('Q-Q Plot {}'.format(i))
        plt.show()

# %%
for i in df_mm.columns:
    if df_mm[i].dtypes != 'object':
        # Create a boxplot
        plt.figure(figsize=(8, 6))
        sns.histplot(df_mm[i], bins=5, kde=False, color='skyblue')
        plt.title('Boxplot of {}'.format(i))
        plt.show()

# %%
df_log = df.apply(lambda x: np.log(x) if x.name != 'color' else x, axis=0)

# %%
df_log.head(3)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0       2.001480         -0.385662         -inf        0.641854  -2.577022
# 1       2.054124         -0.385662         -inf        0.955511  -2.322788
# 2       2.054124         -0.385662    -3.218876        0.832909  -2.385967
#
#    free_sulfur_dioxide  total_sulfur_dioxide   density        pH  sulphates  \
# 0             2.397895              3.526361 -0.002202  1.255616  -0.579818
# 1             3.218876              4.204693 -0.003205  1.163151  -0.385662
# 2             2.708050              3.988984 -0.003005  1.181727  -0.430783
#
#     alcohol   quality color
# 0  2.240710  1.609438   red
# 1  2.282382  1.609438   red
# 2  2.282382  1.609438   red

# %% [markdown]
# # Encoding

# %% [markdown]
# ## onehot encoding

# %%
df_new = pd.get_dummies(df['color'])

# %%
df_new.head()
# Out:
#    red  white
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
df_copy = df.copy()

# %%
# Assuming names is a tuple containing column names
names = ('fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality', 'color')

# Concatenate specific columns from df with df_new
df = pd.concat([df[list(names)], df_new], axis=1)

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color  red  white
# 0      9.4        5   red    1      0
# ...

# %%
df = df.drop('color', axis=1)

# %%
# Adjust the figure size as per your preference
plt.figure(figsize=(12, 10))  

# Compute the correlation matrix using the 'spearman' method
correlation_matrix = df.corr(method='spearman')


sns.heatmap (data=correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')

# Set the title and axis labels
plt.title('Correlation Heatmap')
plt.tight_layout()  # Improve the spacing between the heatmap and the axis labels

plt.show()
# Out:
# C:\Users\sudar\AppData\Local\Temp\ipykernel_12852\2929060018.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='spearman')

# %%
correlation_matrix
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.200272     0.270568
# volatile_acidity           0.200272          1.000000    -0.295129
# citric_acid                0.270568         -0.295129     1.000000
# residual_sugar            -0.032254         -0.064384     0.074920
# chlorides                  0.355964          0.415896    -0.074084
# free_sulfur_dioxide       -0.259914         -0.365673     0.122058
# total_sulfur_dioxide      -0.233259         -0.343534     0.159355
# density                    0.434056          0.261437     0.065690
# pH                        -0.250044          0.194876    -0.285905
# sulphates                  0.220145          0.255042     0.036898
# alcohol                   -0.110650         -0.023924     0.019653
# quality                   -0.098154         -0.257806     0.105711
# red                        0.423682          0.599149    -0.161228
# ...

# %% [markdown]
# # MODEL TRAINING

# %%
# Basic Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Modelling
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from xgboost import XGBRegressor
import warnings

# %%
X = df.drop('quality', axis = 1)
y = df['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)
print(X_train.shape)
print(y_train.shape)
# Out:
# (4547, 13)
# (4547,)

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red  white
# 0      9.4        5    1      0
# ...

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(), 
    "AdaBoost Regressor": AdaBoostRegressor()
}
model_list = []
r2_list =[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)
    
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 0.7355
# - Mean Absolute Error: 0.5705
# - R2 Score: 0.3033
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.7264
# - Mean Absolute Error: 0.5621
# - R2 Score: 0.2769
# ...
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 0.8788
# - Mean Absolute Error: 0.6912
# - R2 Score: 0.0055
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.8522
# - Mean Absolute Error: 0.6624
# - R2 Score: 0.0047
# ...
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 0.7386
# - Mean Absolute Error: 0.5724
# - R2 Score: 0.2975
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.7292
# - Mean Absolute Error: 0.5644
# - R2 Score: 0.2713
# ...
#
#
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.6603
# ...

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False)
# Out:
#                 Model Name  R2_Score
# 5  Random Forest Regressor  0.498323
# 6             XGBRegressor  0.468387
# 7       AdaBoost Regressor  0.286186
# 0        Linear Regression  0.276851
# 2                    Ridge  0.271339
# 3    K-Neighbors Regressor  0.120775
# 4            Decision Tree  0.051868
# 1                    Lasso  0.004730
